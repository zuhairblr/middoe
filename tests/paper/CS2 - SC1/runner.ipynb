# %%
theta = [50000, 75000, 0.4116, 111900, 9905, 30000]
theta_n = [100000, 100000, 1, 100000, 100, 10000]
theta_mins = [10000, 0, 0.1, 50000, 10, 10000]
theta_maxs = [1000000, 200000, 10, 200000, 10000, 200000]

# %%
system = {
    'tvi': {  # Time-variant input variables (models input: tvi), each key is a symbol nad key in tvi as well
        'u1': {  # Temperature (K)
            'stps': 6,  # Number of switching times in CVPs (vector parametrisation resolution in time dimension):
            # Must be a positive integer > 1. swps-1 is the number of steps
            'const': 'inc',  # Constraint type: relative state of signal levels in CVPs
            # 'rel' (relative) ensures relaxation, 'dec' (decreasing) ensures decreasing signal levels, 'inc' (increasing) ensures increasing signal levels
            'max': 306.15,  # Maximum allowable signal level, des_opt space upper bound
            'min': 296.15,  # Minimum allowable signal level, des_opt space lower bound
            'cvp': 'LPF',  # Design CVP method (CPF - constant profile, LPF - linear profile)
            'offl': 0.01,  # minimum allowed perturbation of signal (ratio)
            'offt': 0.3  # minimum allowed perturbation of time (ratio)
        },
    },
    'tvo': {  # Time-variant output variables (responses, measured or unmeasured)
        'y1': {  # response variable, here carbonation efficiency
            'init': 0,  # Initial value for the response variable, it can be a value, or 'variable' for case it is a des_opt decision (time-invariant input variable)
            'meas': True,  # Flag indicating if this variable is directly measurable, if False, it is a virtual output
            'sp': 17,  # the amound of samples per each round (run)
            'unc': 0.05,  # amount of noise (standard deviation) in the measurement, in case of insilico, this is used for simulating a normal distribution of noise to measurement (only measurement)
            'offt': 0.3,  # minimum allowed perturbation of sampling times (ratio)
            'samp_s': 1,  # Matching criterion for models prediction and data alignment
            'samp_f': [0, 16],  # fixed sampling times
        },
        'y2': {  # response variable, here carbonation efficiency
            'init': 0,  # Initial value for the response variable, it can be a value, or 'variable' for case it is a des_opt decision (time-invariant input variable)
            'meas': True,  # Flag indicating if this variable is directly measurable, if False, it is a virtual output
            'sp': 17,  # the amound of samples per each round (run)
            'unc': 0.05,  # amount of noise (standard deviation) in the measurement, in case of insilico, this is used for simulating a normal distribution of noise to measurement (only measurement)
            'offt': 0.3,  # minimum allowed perturbation of sampling times (ratio)
            'samp_s': 1,  # Matching criterion for models prediction and data alignment
            'samp_f': [0, 16],  # fixed sampling times
        },
        'y3': {  # response variable, here carbonation efficiency
            'init': 0,
            # Initial value for the response variable, it can be a value, or 'variable' for case it is a des_opt decision (time-invariant input variable)
            'meas': True,
            # Flag indicating if this variable is directly measurable, if False, it is a virtual output
            'sp': 17,  # the amound of samples per each round (run)
            'unc': 0.05,
            # amount of noise (standard deviation) in the measurement, in case of insilico, this is used for simulating a normal distribution of noise to measurement (only measurement)
            'offt': 0.3,  # minimum allowed perturbation of sampling times (ratio)
            'samp_s': 1,  # Matching criterion for models prediction and data alignment
            'samp_f': [0, 16],  # fixed sampling times
        },
    },
    'tii': {  # Time-invariant input variables (tii)
        'y10': {  # 1st symbolic time-invariant control, Density of solid reactant (kg/m³)
            'max': 1,  # Maximum allowable signal level, des_opt space upper bound
            'min': 0.3  # Minimum allowable signal level, des_opt space upper bound
        },
        'y20': {  # 1st symbolic time-invariant control, Density of solid reactant (kg/m³)
            'max': 1,  # Maximum allowable signal level, des_opt space upper bound
            'min': 0.19  # Minimum allowable signal level, des_opt space upper bound
        },
    },
    'tio': {  # Time-invariant output variables (empty here, could hold steady state responses that hold no dependency)
    },
    't_s': [0, 16],  # Time span  (600 s to 10,800 s), duration of numerical perturbations (the rest is precluded from des_opt)
    't_r': 0.02,  # Time resolution (10 s), minimum time steps for the simulation/des_opt/controls
    't_d': 0.3
}



models = { # Settings related to the rival models and their parameters
    'can_m': ['M'],  # Active solvers (rival models) to be used in the experiment
    'krt': {'M': 'pys'},  # Kernel type for each model, 'pys' for python standalone scripts, 'pym' for middoe.krnl_models, 'gpr' for gPAS models
    # type of the model interface, 'pym' for middoe.krnl_models, 'gpr' for gPAS models, function name for globally defined functions, 'pys' for python standalone scripts
    'creds': {'M': '@@TTmnoa698'},
    # credentials for gPAS models, if not needed, leave empty
    'src': {'M': 'C:/Users/Tadmin/PycharmProjects/middoe/tests/paper/CS2 - SC1/model.py'},
    # for now for gPAS readable files, or python standalone scripts

    'theta': { # Theta parameters for each models
        'M': theta_n
    },
    't_u': { # Maximum bounds for theta parameters (based on normalized to'f20': theta20mins, 1)
        'M': theta_maxs
    },
    't_l': { # Minimum bounds for theta parameters (based on normalized to 1)
        'M': theta_mins
    }
}

# %%
insilicos = { # Settings for the insilico data generation
    'tr_m': 'M', # selected true models (with nominal values)
    'theta': theta,
    'errt': 'rel',  # error type, 'rel' for relative error, 'abs' for absolute error
    'prels': { # classic des_opt settings, sheet name is the round run name, each sheet contains the data for the round, iso space.
        '1': {'u1': 296.15, 'y10': 0.366, 'y20': 0.19},
        '2': {'u1': 306.15, 'y10': 0.366, 'y20': 0.19},
        '3': {'u1': 296.15, 'y10': 0.65, 'y20': 0.595},
        '4': {'u1': 306.15, 'y10': 0.65, 'y20': 0.595},
    }
}

# %%
from middoe.krnl_expera import expera
expera(system, models, insilicos, design_decisions={}, expr=1)
expera(system, models, insilicos, design_decisions={}, expr=2)
expera(system, models, insilicos, design_decisions={}, expr=3)
expera(system, models, insilicos, design_decisions={}, expr=4)
# Out:
# KeyboardInterrupt

# %%
iden_opt = { # Settings for the parameter estimation process
    'meth': 'SLSQP',  #'SLSQP', 'SQP', 'DE', 'NM', 'BFGS'
    'ms': False, # multi starting   # True or False
    'sens_m': 'central', # 'central', 'forward', and 'five' for FDM precision
    'var-cov': 'B', # 'H' for based on hessidan, and 'M' for based on fisher
    'nboot': 100,
    'init': None,   # use 'rand' to have random starting point and use None to start from theta_parameters nominal values (to be avoided in insilico studies)
    'eps': 1e-3,  # perturbation size of parameters in SA FDM method (in a normalized to 1 space)e-
    #usually 1e-3, or None to perform a mesh independency test, and auto adjustment
    'ob': 'WLS',  #loss function, 'LS': least squares, 'MLE': maximum likelihood, 'Chi': chi-square, 'WLS': weighted least squares
    'c_plt': True, # plot the confidence volumes
    'f_plt': True, # plot the fitting results
    'plt_s': True, # show plots while saving
    'log': True # log the results
}

# %%
from middoe.log_utils import  read_excel
data = read_excel('indata')
from middoe.iden_parmest import parmest
resultpr = parmest(system, models, iden_opt, data)
# Out:
# [INFO] Reading from indata.xlsx
# Obj 'WLS'|M|0.108s
# Obj 'WLS'|M|0.100s
# Obj 'WLS'|M|0.124s
# Obj 'WLS'|M|0.124s
# Obj 'WLS'|M|0.111s
# Obj 'WLS'|M|0.108s
# Obj 'WLS'|M|0.107s
# Obj 'WLS'|M|0.067s
# Obj 'WLS'|M|0.101s
# Obj 'WLS'|M|0.095s
# Obj 'WLS'|M|0.115s
# Obj 'WLS'|M|0.103s
# Obj 'WLS'|M|0.101s
# Obj 'WLS'|M|0.101s
# Obj 'WLS'|M|0.108s
# Obj 'WLS'|M|0.068s
# Obj 'WLS'|M|0.103s
# Obj 'WLS'|M|0.131s
# Obj 'WLS'|M|0.106s
# Obj 'WLS'|M|0.119s
# Obj 'WLS'|M|0.111s
# Obj 'WLS'|M|0.116s
# Obj 'WLS'|M|0.112s
# Obj 'WLS'|M|0.081s
# Obj 'WLS'|M|0.131s
# Obj 'WLS'|M|0.115s
# Obj 'WLS'|M|0.117s
# Obj 'WLS'|M|0.104s
# Obj 'WLS'|M|0.111s
# Obj 'WLS'|M|0.117s
# Obj 'WLS'|M|0.117s
# Obj 'WLS'|M|0.071s
# Obj 'WLS'|M|0.098s
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 142.75258355671144
#             Iterations: 4
#             Function evaluations: 33
#             Gradient evaluations: 4
# Obj 'WLS'|M|0.126s
# Obj 'WLS'|M|0.098s
# Obj 'WLS'|M|0.119s
# Obj 'WLS'|M|0.106s
# Obj 'WLS'|M|0.113s
# Obj 'WLS'|M|0.097s
# Obj 'WLS'|M|0.110s
# Obj 'WLS'|M|0.176s
# Obj 'WLS'|M|0.134s
# Obj 'WLS'|M|0.133s
# Obj 'WLS'|M|0.119s
# Obj 'WLS'|M|0.128s
# Obj 'WLS'|M|0.143s
# Obj 'WLS'|M|0.131s
# Obj 'WLS'|M|0.127s
# Obj 'WLS'|M|0.153s
# Obj 'WLS'|M|0.135s
# Obj 'WLS'|M|0.132s
# Obj 'WLS'|M|0.111s
# Obj 'WLS'|M|0.130s
# Obj 'WLS'|M|0.107s
# Obj 'WLS'|M|0.132s
# Obj 'WLS'|M|0.193s
# Obj 'WLS'|M|0.152s
# Obj 'WLS'|M|0.167s
# Obj 'WLS'|M|0.157s
# Obj 'WLS'|M|0.112s
# Obj 'WLS'|M|0.143s
# Obj 'WLS'|M|0.151s
# Obj 'WLS'|M|0.135s
# Obj 'WLS'|M|0.155s
# Obj 'WLS'|M|0.158s
# Obj 'WLS'|M|0.113s
# Obj 'WLS'|M|0.116s
# Obj 'WLS'|M|0.113s
# Obj 'WLS'|M|0.125s
# Obj 'WLS'|M|0.132s
# Obj 'WLS'|M|0.129s
# Obj 'WLS'|M|0.147s
# Obj 'WLS'|M|0.131s
# Obj 'WLS'|M|0.143s
# Obj 'WLS'|M|0.127s
# Obj 'WLS'|M|0.154s
# Obj 'WLS'|M|0.129s
# Obj 'WLS'|M|0.101s
# Obj 'WLS'|M|0.119s
# Obj 'WLS'|M|0.111s
# Obj 'WLS'|M|0.105s
# Obj 'WLS'|M|0.111s
# Obj 'WLS'|M|0.110s
# Obj 'WLS'|M|0.115s
# Obj 'WLS'|M|0.107s
# Obj 'WLS'|M|0.115s
# Obj 'WLS'|M|0.094s
# Obj 'WLS'|M|0.124s
# Obj 'WLS'|M|0.112s
# Obj 'WLS'|M|0.115s
# Obj 'WLS'|M|0.096s
# Obj 'WLS'|M|0.112s
# Obj 'WLS'|M|0.112s
# Obj 'WLS'|M|0.111s
# Obj 'WLS'|M|0.111s
# Obj 'WLS'|M|0.108s
# Obj 'WLS'|M|0.122s
# Obj 'WLS'|M|0.109s
# Obj 'WLS'|M|0.119s
# Obj 'WLS'|M|0.110s
# Obj 'WLS'|M|0.092s
# Obj 'WLS'|M|0.127s
# Obj 'WLS'|M|0.105s
# Obj 'WLS'|M|0.102s
# Obj 'WLS'|M|0.124s
# Obj 'WLS'|M|0.114s

# %%
from middoe.iden_uncert import uncert
uncert_results = uncert(data, resultpr, system, models, iden_opt)
resultun = uncert_results['results']
obs = uncert_results['obs']
# Out:
# INFO:middoe.iden_uncert:Performing mesh-independency test for M
# C:\Users\Tadmin\PycharmProjects\middoe\middoe\iden_uncert.py:906: RuntimeWarning: invalid value encountered in sqrt
#   CI = tcrit * np.sqrt(np.diag(V))
# C:\Users\Tadmin\PycharmProjects\middoe\middoe\iden_uncert.py:907: RuntimeWarning: invalid value encountered in sqrt
#   theta_std = np.sqrt(np.diag(V))
# C:\Users\Tadmin\PycharmProjects\middoe\middoe\iden_uncert.py:908: RuntimeWarning: divide by zero encountered in divide
#   t_values = (theta_full[active_idx] * thetac_arr[active_idx]) / CI
# C:\Users\Tadmin\PycharmProjects\middoe\middoe\iden_uncert.py:912: RuntimeWarning: invalid value encountered in divide
#   Z = LSA * theta_std / resp_sigs[:, None]
# C:\Users\Tadmin\PycharmProjects\middoe\middoe\iden_uncert.py:922: RuntimeWarning: invalid value encountered in scalar divide
#   WLS += (r/s)**2
# C:\Users\Tadmin\PycharmProjects\middoe\middoe\iden_uncert.py:923: RuntimeWarning: divide by zero encountered in log
#   MLE += 0.5*(np.log(2*np.pi*s**2)+(r/s)**2)
# C:\Users\Tadmin\PycharmProjects\middoe\middoe\iden_uncert.py:923: RuntimeWarning: invalid value encountered in scalar divide
#   MLE += 0.5*(np.log(2*np.pi*s**2)+(r/s)**2)
# C:\Users\Tadmin\PycharmProjects\middoe\middoe\iden_uncert.py:924: RuntimeWarning: invalid value encountered in scalar divide
#   Chi += r**2/s**2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 2
#       1 from middoe.iden_uncert import uncert
# ----> 2 uncert_results = uncert(data, resultpr, system, models, iden_opt)
#       3 resultun = uncert_results['results']
#       4 obs = uncert_results['obs']
#
# File ~\PycharmProjects\middoe\middoe\iden_uncert.py:649, in uncert(data, resultpr, system, models, iden_opt, case)
#     647 # If epsilon not provided, run mesh-independency test
#     648 if epsf.get(solver) is None:
# --> 649     epsf[solver] = _fdm_mesh_independency(
#     650         theta=np.ones_like(thetac),
#     651         thetac=thetac,
#     652         solver=solver,
#     653         system=system,
#     654         models=models,
#     655         tv_iphi_vars=tv_iphi_vars,
#     656         ti_iphi_vars=ti_iphi_vars,
#     657         tv_ophi_vars=tv_ophi_vars,
#     658         ti_ophi_vars=ti_ophi_vars,
#     659         data=data,
#     660         sens_method=sens_method,
#     661         varcov=varcov_key,
#     662         resultpr=resultpr
#     663     )
#     665 # Compute uncertainty metrics
#     666 (
#     667     optimized_data,
#     668     LS, MLE, Chi,
#    (...)    690     sens_method=sens_method
#     691 )
#
# File ~\PycharmProjects\middoe\middoe\iden_uncert.py:987, in _fdm_mesh_independency(theta, thetac, solver, system, models, tv_iphi_vars, ti_iphi_vars, tv_ophi_vars, ti_ophi_vars, data, sens_method, varcov, resultpr)
#     985 for eps in eps_values:
#     986     try:
# --> 987         out = _uncert_metrics(
#     988             theta, data, [solver], thetac, {solver:eps}, [True]*len(theta),
#     989             ti_iphi_vars, tv_iphi_vars, tv_ophi_vars, ti_ophi_vars,
#     990             system, models, varcov, resultpr, sens_method=sens_method
#     991         )
#     992         V = out[6]  # returned V_matrix
#     993         eigs.append(np.linalg.eigvalsh(V))
#
# File ~\PycharmProjects\middoe\middoe\iden_uncert.py:811, in _uncert_metrics(theta, data, active_solvers, thetac, eps, thetas, ti_iphi_vars, tv_iphi_vars, tv_ophi_vars, ti_ophi_vars, system, models, varcov, resultpr, sens_method)
#     809 thp = theta_full.copy(); thp[p] += h
#     810 thm = theta_full.copy(); thm[p] -= h
# --> 811 tvp, tip, _ = simula(
#     812     t_all, swps, ti_in,
#     813     {v:1 for v in ti_iphi_vars}, {v:1 for v in tv_iphi_vars}, 1,
#     814     thp, thetac_arr, cvp, tv_in, solver, system, models
#     815 )
#     816 tvm, tim, _ = simula(
#     817     t_all, swps, ti_in,
#     818     {v:1 for v in ti_iphi_vars}, {v:1 for v in tv_iphi_vars}, 1,
#     819     thm, thetac_arr, cvp, tv_in, solver, system, models
#     820 )
#     821 perturbed[p] = ('central', (tvp, tip, tvm, tim))
#
# File ~\PycharmProjects\middoe\middoe\krnl_simula.py:129, in simula(t, swps, uphi, uphisc, uphitsc, utsc, utheta, uthetac, cvp, uphit, model_name, system, models)
#      98     raise KeyError(f"Model type for '{model_name}' not recognized or not callable.")
#     100 # # Determine model source based on model type
#     101 # model_type = models['krt'].get(model_name)
#     102 #
#    (...)    126 #     except KeyError:
#     127 #         raise KeyError(f"Model '{model_name}' not found or not callable. Check models dictionary.")
# --> 129 tv_ophi, ti_ophi, phit = _backscal(
#     130     t, swps, uphi, uphisc, uphitsc, utsc, utheta, uthetac,
#     131     cvp, uphit, model, system, models, model_name
#     132 )
#     133 return tv_ophi, ti_ophi, phit
#
# File ~\PycharmProjects\middoe\middoe\krnl_simula.py:248, in _backscal(t, swps, uphi, uphisc, uphitsc, utsc, utheta, uthetac, cvp, uphit, model, system, models, model_name)
#     245 t_scaled = (np.array(t) * utsc).tolist()
#     247 # Select the model and perform the integration
# --> 248 tv_ophi, ti_ophi, phit = solver_selector(model, t_scaled, y0, phi, phit, theta, models, model_name, system)
#     252 return tv_ophi, ti_ophi, phit
#
# File ~\PycharmProjects\middoe\middoe\krnl_simula.py:286, in solver_selector(model, t, y0, phi, phit, theta, models, model_name, system)
#     283 spec.loader.exec_module(module)
#     285 external_solver_func = getattr(module, 'solve_model')
# --> 286 external_result = external_solver_func(t, y0, phi, phit, theta)
#     288 tv_ophi = external_result.get('tvo', {})
#     289 ti_ophi = external_result.get('tio', {})
#
# File C:/Users/Tadmin/PycharmProjects/middoe/tests/paper/CS2 - SC1/model.py:266, in solve_model(t, y0, tii, tvi, theta)
#     257 # initial conditions as float64
#     258 y0_arr = np.array([
#     259     tii_vals['y10'],
#     260     tii_vals['y20'],
#    (...)    263     np.float64(0.0)
#     264 ], dtype=np.float64)
# --> 266 sol = solve_ivp(
#     267     fun=model_rhs,
#     268     t_span=(t[0], t[-1]),
#     269     y0=y0_arr,
#     270     args=(tii_vals, {'u1': u1}, theta, te),
#     271     t_eval=t,
#     272     method='BDF',
#     273     rtol=np.float64(1e-6),
#     274     atol=np.float64(1e-9)
#     275 )
#     277 return {
#     278     'tvo': {
#     279         'y1': sol.y[0].astype(np.float64).tolist(),  # SM
#    (...)    283     'tio': {}
#     284 }
#
# File ~\PycharmProjects\middoe\.venv\Lib\site-packages\scipy\integrate\_ivp\ivp.py:655, in solve_ivp(fun, t_span, y0, method, t_eval, dense_output, events, vectorized, args, **options)
#     653 status = None
#     654 while status is None:
# --> 655     message = solver.step()
#     657     if solver.status == 'finished':
#     658         status = 0
#
# File ~\PycharmProjects\middoe\.venv\Lib\site-packages\scipy\integrate\_ivp\base.py:197, in OdeSolver.step(self)
#     195 else:
#     196     t = self.t
# --> 197     success, message = self._step_impl()
#     199     if not success:
#     200         self.status = 'failed'
#
# File ~\PycharmProjects\middoe\.venv\Lib\site-packages\scipy\integrate\_ivp\bdf.py:446, in BDF._step_impl(self)
#     444 factor = min(MAX_FACTOR, safety * np.max(factors))
#     445 self.h_abs *= factor
# --> 446 change_D(D, order, factor)
#     447 self.n_equal_steps = 0
#     448 self.LU = None
#
# File ~\PycharmProjects\middoe\.venv\Lib\site-packages\scipy\integrate\_ivp\bdf.py:32, in change_D(D, order, factor)
#      30 R = compute_R(order, factor)
#      31 U = compute_R(order, 1)
# ---> 32 RU = R.dot(U)
#      33 D[:order + 1] = np.dot(RU.T, D[:order + 1])
#
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~\PycharmProjects\middoe\.venv\Lib\site-packages\IPython\core\async_helpers.py:128, in _pseudo_sync_runner(coro)
#     120 """
#     121 A runner that does not really allow async execution, and just advance the coroutine.
#     122
#    (...)    125 Credit to Nathaniel Smith
#     126 """
#     127 try:
# --> 128     coro.send(None)
#     129 except StopIteration as exc:
#     130     return exc.value
#
# File ~\PycharmProjects\middoe\.venv\Lib\site-packages\IPython\core\interactiveshell.py:3384, in InteractiveShell.run_cell_async(self, raw_cell, store_history, silent, shell_futures, transformed_cell, preprocessing_exc_tuple, cell_id)
#    3380 exec_count = self.execution_count
#    3381 if result.error_in_exec:
#    3382     # Store formatted traceback and error details
#    3383     self.history_manager.exceptions[exec_count] = (
# -> 3384         self._format_exception_for_storage(result.error_in_exec)
#    3385     )
#    3387 # Each cell is a *single* input, regardless of how many lines it has
#    3388 self.execution_count += 1
#
# File ~\PycharmProjects\middoe\.venv\Lib\site-packages\IPython\core\interactiveshell.py:3438, in InteractiveShell._format_exception_for_storage(self, exception, filename, running_compiled_code)
#    3435         stb = evalue._render_traceback_()
#    3436     else:
#    3437         # Otherwise, use InteractiveTB to format the traceback.
# -> 3438         stb = self.InteractiveTB.structured_traceback(
#    3439             etype, evalue, tb, tb_offset=1
#    3440         )
#    3441 except Exception:
#    3442     # In case formatting fails, fallback to Python's built-in formatting.
#    3443     stb = traceback.format_exception(etype, evalue, tb)
#
# File ~\PycharmProjects\middoe\.venv\Lib\site-packages\IPython\core\ultratb.py:1182, in AutoFormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#    1180 else:
#    1181     self.tb = etb
# -> 1182 return FormattedTB.structured_traceback(
#    1183     self, etype, evalue, etb, tb_offset, context
#    1184 )
#
# File ~\PycharmProjects\middoe\.venv\Lib\site-packages\IPython\core\ultratb.py:1053, in FormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#    1050 mode = self.mode
#    1051 if mode in self.verbose_modes:
#    1052     # Verbose modes need a full traceback
# -> 1053     return VerboseTB.structured_traceback(
#    1054         self, etype, evalue, etb, tb_offset, context
#    1055     )
#    1056 elif mode == "Docs":
#    1057     # return DocTB
#    1058     return DocTB(
#    1059         theme_name=self._theme_name,
#    1060         call_pdb=self.call_pdb,
#    (...)   1068         etype, evalue, etb, tb_offset, 1
#    1069     )  # type: ignore[arg-type]
#
# File ~\PycharmProjects\middoe\.venv\Lib\site-packages\IPython\core\ultratb.py:861, in VerboseTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     852 def structured_traceback(
#     853     self,
#     854     etype: type,
#    (...)    858     context: int = 5,
#     859 ) -> list[str]:
#     860     """Return a nice text document describing the traceback."""
# --> 861     formatted_exceptions: list[list[str]] = self.format_exception_as_a_whole(
#     862         etype, evalue, etb, context, tb_offset
#     863     )
#     865     termsize = min(75, get_terminal_size()[0])
#     866     theme = theme_table[self._theme_name]
#
# File ~\PycharmProjects\middoe\.venv\Lib\site-packages\IPython\core\ultratb.py:773, in VerboseTB.format_exception_as_a_whole(self, etype, evalue, etb, context, tb_offset)
#     763         frames.append(
#     764             theme_table[self._theme_name].format(
#     765                 [
#    (...)    770             )
#     771         )
#     772         skipped = 0
# --> 773     frames.append(self.format_record(record))
#     774 if skipped:
#     775     frames.append(
#     776         theme_table[self._theme_name].format(
#     777             [
#    (...)    782         )
#     783     )
#
# File ~\PycharmProjects\middoe\.venv\Lib\site-packages\IPython\core\ultratb.py:651, in VerboseTB.format_record(self, frame_info)
#     648 result += ", " if call else ""
#     649 result += f"{call}\n"
#     650 result += theme_table[self._theme_name].format(
# --> 651     _format_traceback_lines(
#     652         frame_info.lines,
#     653         theme_table[self._theme_name],
#     654         self.has_colors,
#     655         lvals_toks,
#     656     )
#     657 )
#     658 return result
#
# File ~\PycharmProjects\middoe\.venv\Lib\site-packages\IPython\core\tbtools.py:99, in _format_traceback_lines(lines, theme, has_colors, lvals_toks)
#      96     continue
#      98 lineno = stack_line.lineno
# ---> 99 line = stack_line.render(pygmented=has_colors).rstrip("\n") + "\n"
#     100 if stack_line.is_current:
#     101     # This is the line with the error
#     102     pad = numbers_width - len(str(lineno))
#
# File ~\PycharmProjects\middoe\.venv\Lib\site-packages\stack_data\core.py:391, in Line.render(self, markers, strip_leading_indent, pygmented, escape_html)
#     389 if pygmented and self.frame_info.scope:
#     390     assert_(not markers, ValueError("Cannot use pygmented with markers"))
# --> 391     start_line, lines = self.frame_info._pygmented_scope_lines
#     392     result = lines[self.lineno - start_line]
#     393     if strip_leading_indent:
#
# File ~\PycharmProjects\middoe\.venv\Lib\site-packages\stack_data\utils.py:145, in cached_property.cached_property_wrapper(self, obj, _cls)
#     142 if obj is None:
#     143     return self
# --> 145 value = obj.__dict__[self.func.__name__] = self.func(obj)
#     146 return value
#
# File ~\PycharmProjects\middoe\.venv\Lib\site-packages\stack_data\core.py:824, in FrameInfo._pygmented_scope_lines(self)
#     821     ranges = []
#     823 code = atext.get_text(scope)
# --> 824 lines = _pygmented_with_ranges(formatter, code, ranges)
#     826 start_line = self.source.line_range(scope)[0]
#     828 return start_line, lines
#
# File ~\PycharmProjects\middoe\.venv\Lib\site-packages\stack_data\utils.py:164, in _pygmented_with_ranges(formatter, code, ranges)
#     161             length += len(value)
#     162             yield ttype, value
# --> 164 lexer = MyLexer(stripnl=False)
#     165 try:
#     166     highlighted = pygments.highlight(code, lexer, formatter)
#
# File ~\PycharmProjects\middoe\.venv\Lib\site-packages\pygments\lexer.py:660, in RegexLexerMeta.__call__(cls, *args, **kwds)
#     658         pass
#     659     else:
# --> 660         cls._tokens = cls.process_tokendef('', cls.get_tokendefs())
#     662 return type.__call__(cls, *args, **kwds)
#
# File ~\PycharmProjects\middoe\.venv\Lib\site-packages\pygments\lexer.py:599, in RegexLexerMeta.process_tokendef(cls, name, tokendefs)
#     597 tokendefs = tokendefs or cls.tokens[name]
#     598 for state in list(tokendefs):
# --> 599     cls._process_state(tokendefs, processed, state)
#     600 return processed
#
# File ~\PycharmProjects\middoe\.venv\Lib\site-packages\pygments\lexer.py:563, in RegexLexerMeta._process_state(cls, unprocessed, processed, state)
#     560 if isinstance(tdef, include):
#     561     # it's a state reference
#     562     assert tdef != state, f"circular state reference {state!r}"
# --> 563     tokens.extend(cls._process_state(unprocessed, processed,
#     564                                      str(tdef)))
#     565     continue
#     566 if isinstance(tdef, _inherit):
#     567     # should be processed already, but may not in the case of:
#     568     # 1. the state has no counterpart in any parent
#     569     # 2. the state includes more than one 'inherit'
#
# File ~\PycharmProjects\middoe\.venv\Lib\site-packages\pygments\lexer.py:563, in RegexLexerMeta._process_state(cls, unprocessed, processed, state)
#     560 if isinstance(tdef, include):
#     561     # it's a state reference
#     562     assert tdef != state, f"circular state reference {state!r}"
# --> 563     tokens.extend(cls._process_state(unprocessed, processed,
#     564                                      str(tdef)))
#     565     continue
#     566 if isinstance(tdef, _inherit):
#     567     # should be processed already, but may not in the case of:
#     568     # 1. the state has no counterpart in any parent
#     569     # 2. the state includes more than one 'inherit'
#
# File ~\PycharmProjects\middoe\.venv\Lib\site-packages\pygments\lexer.py:579, in RegexLexerMeta._process_state(cls, unprocessed, processed, state)
#     576 assert type(tdef) is tuple, f"wrong rule def {tdef!r}"
#     578 try:
# --> 579     rex = cls._process_regex(tdef[0], rflags, state)
#     580 except Exception as err:
#     581     raise ValueError(f"uncompilable regex {tdef[0]!r} in state {state!r} of {cls!r}: {err}") from err
#
# File ~\PycharmProjects\middoe\.venv\Lib\site-packages\pygments\lexer.py:507, in RegexLexerMeta._process_regex(cls, regex, rflags, state)
#     505 """Preprocess the regular expression component of a token definition."""
#     506 if isinstance(regex, Future):
# --> 507     regex = regex.get()
#     508 return re.compile(regex, rflags).match
#
# File ~\PycharmProjects\middoe\.venv\Lib\site-packages\pygments\lexer.py:495, in words.get(self)
#     494 def get(self):
# --> 495     return regex_opt(self.words, prefix=self.prefix, suffix=self.suffix)
#
# File ~\PycharmProjects\middoe\.venv\Lib\site-packages\pygments\regexopt.py:91, in regex_opt(strings, prefix, suffix)
#      83 """Return a compiled regex that matches any string in the given list.
#      84
#      85 The strings to match must be literal strings, not regexes.  They will be
#    (...)     88 *prefix* and *suffix* are pre- and appended to the final regex.
#      89 """
#      90 strings = sorted(strings)
# ---> 91 return prefix + regex_opt_inner(strings, '(') + suffix
#
# File ~\PycharmProjects\middoe\.venv\Lib\site-packages\pygments\regexopt.py:77, in regex_opt_inner(strings, open_paren)
#      71     return open_paren \
#      72         + regex_opt_inner(sorted(s[:-slen] for s in strings), '(?:') \
#      73         + escape(suffix[::-1]) + close_paren
#      74 # recurse on common 1-string prefixes
#      75 # print '-> last resort'
#      76 return open_paren + \
# ---> 77     '|'.join(regex_opt_inner(list(group[1]), '')
#      78              for group in groupby(strings, lambda s: s[0] == first[0])) \
#      79     + close_paren
#
# File ~\PycharmProjects\middoe\.venv\Lib\site-packages\pygments\regexopt.py:77, in <genexpr>(.0)
#      71     return open_paren \
#      72         + regex_opt_inner(sorted(s[:-slen] for s in strings), '(?:') \
#      73         + escape(suffix[::-1]) + close_paren
#      74 # recurse on common 1-string prefixes
#      75 # print '-> last resort'
#      76 return open_paren + \
# ---> 77     '|'.join(regex_opt_inner(list(group[1]), '')
#      78              for group in groupby(strings, lambda s: s[0] == first[0])) \
#      79     + close_paren
#
# File ~\PycharmProjects\middoe\.venv\Lib\site-packages\pygments\regexopt.py:77, in regex_opt_inner(strings, open_paren)
#      71     return open_paren \
#      72         + regex_opt_inner(sorted(s[:-slen] for s in strings), '(?:') \
#      73         + escape(suffix[::-1]) + close_paren
#      74 # recurse on common 1-string prefixes
#      75 # print '-> last resort'
#      76 return open_paren + \
# ---> 77     '|'.join(regex_opt_inner(list(group[1]), '')
#      78              for group in groupby(strings, lambda s: s[0] == first[0])) \
#      79     + close_paren
#
# File ~\PycharmProjects\middoe\.venv\Lib\site-packages\pygments\regexopt.py:77, in <genexpr>(.0)
#      71     return open_paren \
#      72         + regex_opt_inner(sorted(s[:-slen] for s in strings), '(?:') \
#      73         + escape(suffix[::-1]) + close_paren
#      74 # recurse on common 1-string prefixes
#      75 # print '-> last resort'
#      76 return open_paren + \
# ---> 77     '|'.join(regex_opt_inner(list(group[1]), '')
#      78              for group in groupby(strings, lambda s: s[0] == first[0])) \
#      79     + close_paren
#
#     [... skipping similar frames: <genexpr> at line 77 (15 times), regex_opt_inner at line 77 (15 times)]
#
# File ~\PycharmProjects\middoe\.venv\Lib\site-packages\pygments\regexopt.py:77, in regex_opt_inner(strings, open_paren)
#      71     return open_paren \
#      72         + regex_opt_inner(sorted(s[:-slen] for s in strings), '(?:') \
#      73         + escape(suffix[::-1]) + close_paren
#      74 # recurse on common 1-string prefixes
#      75 # print '-> last resort'
#      76 return open_paren + \
# ---> 77     '|'.join(regex_opt_inner(list(group[1]), '')
#      78              for group in groupby(strings, lambda s: s[0] == first[0])) \
#      79     + close_paren
#
# File ~\PycharmProjects\middoe\.venv\Lib\site-packages\pygments\regexopt.py:77, in <genexpr>(.0)
#      71     return open_paren \
#      72         + regex_opt_inner(sorted(s[:-slen] for s in strings), '(?:') \
#      73         + escape(suffix[::-1]) + close_paren
#      74 # recurse on common 1-string prefixes
#      75 # print '-> last resort'
#      76 return open_paren + \
# ---> 77     '|'.join(regex_opt_inner(list(group[1]), '')
#      78              for group in groupby(strings, lambda s: s[0] == first[0])) \
#      79     + close_paren
#
# File ~\PycharmProjects\middoe\.venv\Lib\site-packages\pygments\regexopt.py:63, in regex_opt_inner(strings, open_paren)
#      59     plen = len(prefix)
#      60     # we have a prefix for all strings
#      61     # print '-> prefix:', prefix
#      62     return open_paren + escape(prefix) \
# ---> 63         + regex_opt_inner([s[plen:] for s in strings], '(?:') \
#      64         + close_paren
#      65 # is there a suffix?
#      66 strings_rev = [s[::-1] for s in strings]
#
# File ~\PycharmProjects\middoe\.venv\Lib\site-packages\pygments\regexopt.py:72, in regex_opt_inner(strings, open_paren)
#      69     slen = len(suffix)
#      70     # print '-> suffix:', suffix[::-1]
#      71     return open_paren \
# ---> 72         + regex_opt_inner(sorted(s[:-slen] for s in strings), '(?:') \
#      73         + escape(suffix[::-1]) + close_paren
#      74 # recurse on common 1-string prefixes
#      75 # print '-> last resort'
#      76 return open_paren + \
#      77     '|'.join(regex_opt_inner(list(group[1]), '')
#      78              for group in groupby(strings, lambda s: s[0] == first[0])) \
#      79     + close_paren
#
# File ~\PycharmProjects\middoe\.venv\Lib\site-packages\pygments\regexopt.py:67, in regex_opt_inner(strings, open_paren)
#      65 # is there a suffix?
#      66 strings_rev = [s[::-1] for s in strings]
# ---> 67 suffix = commonprefix(strings_rev)
#      68 if suffix:
#      69     slen = len(suffix)
#
# File <frozen genericpath>:89, in commonprefix(m)
#
# KeyboardInterrupt:

# %%
from middoe.sc_estima import estima
j = 4
ranking, k_optimal_value, rCC_values, J_k_values, best_uncert_result = estima(resultun, system, models, iden_opt, j, data)
# Out:
# Estimability analysis for round 4 is running
# Parameter ranking from most estimable to least estimable for M in round 4: [2, 4, 3, 0, 5, 1]
# J_theta : 772654.6475464713
# INFO:middoe.iden_uncert:Fisher matrix condition number: 1.00e+00
# P-value of model:M is 100.0 for model discrimination
# J_k 1 parameters: 763778.4431961381
# rC 1 parameters: -1775.240870066639
# rCKub parameters: -507.21167716189683
# rCC parameters: -30.250695069160525
# INFO:middoe.iden_uncert:Fisher matrix condition number: 2.11e+10
# WARNING:middoe.iden_uncert:Fisher matrix is ill-conditioned. Confidence intervals may be unreliable.
# P-value of model:M is 100.0 for model discrimination
# J_k 2 parameters: 763050.293263694
# rC 2 parameters: -2401.0885706943227
# rCKub parameters: -800.3628568981076
# rCC parameters: -38.16013604276702
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 3
#       1 from middoe.sc_estima import estima
#       2 j = 4
# ----> 3 ranking, k_optimal_value, rCC_values, J_k_values, best_uncert_result = estima(resultun, system, models, iden_opt, j, data)
#
# File ~\PycharmProjects\middoe\middoe\sc_estima.py:39, in estima(result, system, models, iden_opt, round, data)
#      36 ranking_known = parameter_ranking(Z)
#      37 print(f"Parameter ranking from most estimable to least estimable for {solver} in round {round}: {ranking_known}")
# ---> 39 k_optimal, rCC, J_k, best_uncert_result = parameter_selection(
#      40     n_parameters, ranking_known, system, models,
#      41     iden_opt, solver, round, data, result
#      42 )
#      43 print(f"Optimal number of parameters to estimate for {solver}: {k_optimal}")
#      45 rankings[solver] = ranking_known
#
# File ~\PycharmProjects\middoe\middoe\sc_estima.py:151, in parameter_selection(n_parameters, ranking_known, system, models, iden_opt, solvera, round, data, result)
#     148 models_k['mutation'][solvera] = selected_mask
#     150 # Run estimation and uncertainty analysis with k parameters
# --> 151 results_k_params = parmest(system_k, models_k, iden_opt_k, data, case='freeze')
#     152 uncert_results_k = uncert(data, results_k_params, system_k, models_k, iden_opt_k, case='freeze')
#     153 uncert_results_list.append(uncert_results_k)
#
# File ~\PycharmProjects\middoe\middoe\iden_parmest.py:52, in parmest(system, models, iden_opt, data, case)
#      49 n_starts = max(1, int(0.7 * total_cpus)) if multi else 1
#      51 if multi:
# ---> 52     results = _multi_start_runner(
#      53         active_models, theta_parameters, bound_max, bound_min, mutation,
#      54         objf, method, data, system, models, logging, n_starts
#      55     )
#      56 else:
#      57     results = _runner(
#      58         active_models, theta_parameters, bound_max, bound_min, mutation,
#      59         objf, x0_dict, method, data, system, models, logging
#      60     )
#
# File ~\PycharmProjects\middoe\middoe\iden_parmest.py:123, in _multi_start_runner(***failed resolving arguments***)
#     121 with ProcessPoolExecutor(max_workers=n_workers) as executor:
#     122     futures = [executor.submit(_run_task_wrapper, t) for t in tasks]
# --> 123     for future in as_completed(futures):
#     124         solver, result = future.result()
#     125         try:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\concurrent\futures\_base.py:243, in as_completed(fs, timeout)
#     238     if wait_timeout < 0:
#     239         raise TimeoutError(
#     240                 '%d (of %d) futures unfinished' % (
#     241                 len(pending), total_futures))
# --> 243 waiter.event.wait(wait_timeout)
#     245 with waiter.lock:
#     246     finished = waiter.finished_futures
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\threading.py:655, in Event.wait(self, timeout)
#     653 signaled = self._flag
#     654 if not signaled:
# --> 655     signaled = self._cond.wait(timeout)
#     656 return signaled
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\threading.py:355, in Condition.wait(self, timeout)
#     353 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     354     if timeout is None:
# --> 355         waiter.acquire()
#     356         gotit = True
#     357     else:
#
# KeyboardInterrupt:

# %%
from middoe.log_utils import  save_rounds
round_data={}
round = 1
save_rounds(round, resultun,  'preliminary', round_data, models, iden_opt, obs, data, system, ranking= ranking, k_optimal_value= k_optimal_value, rCC_values= rCC_values, J_k_values= J_k_values,  best_uncert_result= best_uncert_result)
# save_rounds(round, resultun,  'preliminary', round_data, models, iden_opt, obs, data, system)
# Out:
# C:\Users\Tadmin\PycharmProjects\middoe\middoe\iden_utils.py:531: RuntimeWarning: invalid value encountered in sqrt
#   width, height = 2 * np.sqrt(vals)
# reference t value for model M and round 1: 1.9908470688116904
# estimated t values for model M and round 1: [1.42339990e+06 6.00394179e+11 9.34233608e+01 3.83236637e+09
#  1.68532143e+00 1.94498088e+10]
# P-value for model M and round 1: 100.0
# eps for model M and round 1: 0.001
# {'M': np.float64(1.9908470688116904)}

# %%
models['can_m'].remove('MIV')
models['can_m'].remove('MIII')

# %%
des_opt = { # Design settings for the experiment
    'eps': 1e-3, #perturbation size of parameters in SA FDM method (in a normalized to 1 space)
    'meth': 'PS',  # optimisation method, 'G': Global Differential Evolution, 'L': Local Pattern Search, 'GL': Global Differential Evolution refined with Local Pattern Search
    'md_ob': 'HR',     # MD optimality criterion, 'HR': Hunter and Reiner, 'BFF': Buzzi-Ferraris and Forzatti
    'pp_ob': 'E',  # PP optimality criterion, 'D', 'A', 'E', 'ME'
    'plt': True,  # Plot the results
    'itr': {
        'pps': 30, # population size
        'maxmd': 200, # maximum number of MD runs
        'tolmd': 1, # tolerance for MD optimization
        'maxpp':20 ,# maximum number of PP runs
        'tolpp': 1, # tolerance for PP optimization
    }
}

# %%
from middoe.des_md import mbdoe_md
designs = mbdoe_md(des_opt, system, models, round=2, num_parallel_runs=16)

# %%
from middoe.krnl_expera import expera
expera(system, models, insilicos, designs, expr=3, swps=designs['swps'])
# Out:
# [✓] In-silico data saved to: C:\Users\Tadmin\PycharmProjects\middoe\tests\paper\CS1\indata.xlsx
# [INFO] Model used         : MI
# [INFO] Design case        : MBDoE
# [INFO] Responses simulated:
#    - y1         | measurable      | std.dev = 0.08
#    - y2         | measurable      | std.dev = 0.08
# (WindowsPath('C:/Users/Tadmin/PycharmProjects/middoe/tests/paper/CS1/indata.xlsx'),
#       MES_X:y1  MES_Y:y1  MES_E:y1  MES_X:y2   MES_Y:y2  MES_E:y2  X:all  y10  \
#  0       19.20  1.998572  0.149764     19.20   7.395420  0.684946   0.00  1.0
#  1       20.80  1.899316  0.167887     20.80  10.875609  0.865567   0.16  1.0
#  2       25.60  2.868255  0.249398     25.60  13.294035  1.201512   0.32  1.0
#  3       33.28  5.863831  0.480166     33.28  16.254845  1.271651   0.48  1.0
#  4       36.96  7.671981  0.664324     36.96  13.596411  1.088642   0.64  1.0
#  ..        ...       ...       ...       ...        ...       ...    ...  ...
#  246       NaN       NaN       NaN       NaN        NaN       NaN  39.36  1.0
#  247       NaN       NaN       NaN       NaN        NaN       NaN  39.52  1.0
#  248       NaN       NaN       NaN       NaN        NaN       NaN  39.68  1.0
#  249       NaN       NaN       NaN       NaN        NaN       NaN  39.84  1.0
#  250       NaN       NaN       NaN       NaN        NaN       NaN  40.00  1.0
#
#             u1    u2       CVP:u1 CVP:u2             u1l        u2l    u1t  \
#  0    0.051177   5.0  None    CPF    LPF  None  0.051177   5.000000   0.00
#  1    0.051177   5.0  None    NaN    NaN  None  0.082283   5.000000   1.76
#  2    0.051177   5.0  None    NaN    NaN  None  0.069189   7.596724  22.24
#  3    0.051177   5.0  None    NaN    NaN  None  0.111316   5.014648  28.16
#  4    0.051177   5.0  None    NaN    NaN  None  0.067649  35.000000  28.64
#  ..        ...   ...   ...    ...    ...   ...       ...        ...    ...
#  246  0.067649  35.0  None    NaN    NaN  None       NaN        NaN    NaN
#  247  0.067649  35.0  None    NaN    NaN  None       NaN        NaN    NaN
#  248  0.067649  35.0  None    NaN    NaN  None       NaN        NaN    NaN
#  249  0.067649  35.0  None    NaN    NaN  None       NaN        NaN    NaN
#  250  0.067649  35.0  None    NaN    NaN  None       NaN        NaN    NaN
#
#         u2t
#  0     0.00
#  1     7.52
#  2     8.48
#  3    10.24
#  4    20.48
#  ..     ...
#  246    NaN
#  247    NaN
#  248    NaN
#  249    NaN
#  250    NaN
#
#  [251 rows x 18 columns])

# %%
data = read_excel('indata')
resultpr = parmest(system, models, iden_opt, data)
uncert_results = uncert(data, resultpr, system, models, iden_opt)
resultun = uncert_results['results']
obs = uncert_results['obs']
# Out:
# [INFO] Reading from indata.xlsx
# Objective function: 'WLS'| model 'MI' | CPU time 0.1307 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1318 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1139 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1122 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1159 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1330 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1263 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1286 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1346 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1401 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1355 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1253 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1220 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1326 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1231 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1159 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1305 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1259 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1083 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1131 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1113 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1159 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1106 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1136 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1106 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1099 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1187 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1132 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1166 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1186 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1134 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1117 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1095 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1129 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1117 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1237 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1174 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1101 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1128 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1162 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1077 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1101 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1092 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1111 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1174 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1150 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1185 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1220 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1246 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1278 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1072 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1124 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1134 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1162 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1208 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1257 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1250 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1110 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1106 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1100 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1085 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1175 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1099 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1158 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1078 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1138 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1099 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1149 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1050 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1102 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1157 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1105 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1133 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1100 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1189 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1272 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1094 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1068 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1069 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1129 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1175 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1143 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1166 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1147 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1137 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1157 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1153 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1125 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1150 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1126 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1103 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1109 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1116 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1111 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1084 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1446 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1216 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1196 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1165 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1131 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1173 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1175 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1189 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1198 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1233 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1103 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1168 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1121 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1215 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1079 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1124 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1107 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1092 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1158 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1157 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1215 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1195 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1371 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1210 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1165 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1245 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1115 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1138 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1245 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.2450 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1059 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1084 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1140 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1088 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1197 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1079 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1207 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1068 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1121 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1109 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1104 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1116 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1112 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1061 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1112 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1122 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1144 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1133 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1194 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1137 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1124 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1102 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1084 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1208 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1155 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1078 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1168 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1238 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1305 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1198 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1220 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1251 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1287 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1198 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1249 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1212 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1179 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1213 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1177 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1144 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1073 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1073 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1024 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1051 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1058 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1238 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1318 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1185 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1294 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1227 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1257 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1138 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1133 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1110 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1181 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1071 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1148 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1065 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1081 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1087 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1096 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1080 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1111 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1113 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1090 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1177 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1568 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1107 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1214 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1097 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1111 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1066 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1136 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1088 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1067 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1040 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1078 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1063 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1063 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1040 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1069 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1011 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1077 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1062 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1004 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1038 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1175 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1163 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1063 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1064 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1379 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1343 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1294 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1308 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1310 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1317 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1304 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1260 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1364 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1439 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1155 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1176 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1226 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1162 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1161 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1230 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1129 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1117 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1153 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1083 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1244 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1132 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1158 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1128 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1135 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1125 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1139 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1139 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1122 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1107 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1134 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1447 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1475 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1369 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1419 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1445 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1396 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1395 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1474 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1219 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1424 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1248 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1449 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1354 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1526 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1168 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1897 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1123 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1358 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1277 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1328 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1313 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1289 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1346 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1355 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1319 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1684 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1323 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1279 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1223 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1326 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1188 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1415 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1388 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1358 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1257 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1277 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1307 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1211 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1246 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1365 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1247 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1424 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1239 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1247 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1388 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1199 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1128 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1136 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1187 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1156 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1114 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1113 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1187 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1130 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1189 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1368 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1117 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1203 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1309 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1184 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1159 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1125 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1141 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1161 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1165 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1126 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1127 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1216 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1152 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1178 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1208 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1171 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1149 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1226 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1225 seconds.
# C:\Users\Tadmin\PycharmProjects\middoe\.venv\Lib\site-packages\scipy\optimize\_differentiable_functions.py:231: UserWarning: delta_grad == 0.0. Check if the approximated function is linear. If the function is linear better results can be obtained by defining the Hessian as zero instead of using quasi-Newton approximations.
#   self.H.update(self.x - self.x_prev, self.g - self.g_prev)
# Objective function: 'WLS'| model 'MI' | CPU time 0.1296 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1186 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1177 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1204 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1209 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1457 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1157 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1107 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1181 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1132 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1103 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1109 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1131 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1190 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1110 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1086 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1133 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1206 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1158 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1183 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1174 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1117 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1183 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1104 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1117 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1109 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1158 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1127 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1176 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1149 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1171 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1156 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1151 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1109 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1195 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1125 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1141 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1149 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1229 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1254 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1251 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1282 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1280 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1165 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1178 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1182 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1143 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1117 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1208 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1121 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1125 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1126 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1252 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1186 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1139 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1126 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1195 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1200 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1265 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1175 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1166 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1157 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1245 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1598 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1106 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1145 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1125 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1110 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1105 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1104 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1150 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1065 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1049 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1046 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1071 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1184 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1360 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1071 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1064 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1153 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1173 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1150 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1109 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1095 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1108 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1100 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1078 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1070 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1140 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1161 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1137 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1153 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1179 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1272 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1160 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1332 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1219 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1136 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1096 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1077 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1092 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1315 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1309 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1656 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1061 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1115 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1146 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1158 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1100 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1099 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1113 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1076 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1383 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1364 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1147 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1118 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1141 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1082 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1084 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1144 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1084 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1079 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1078 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1118 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1112 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1094 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1100 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1131 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1133 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1122 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1105 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1084 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1083 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1102 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1108 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1156 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1329 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1114 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1080 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1205 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1181 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1143 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1134 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1100 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1082 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1109 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1203 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1083 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1359 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1071 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1079 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1061 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1089 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1078 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1075 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1237 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1226 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1315 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1319 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1203 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1103 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1110 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1094 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1093 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1111 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1082 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1121 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1066 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1213 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1101 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1145 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1072 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1104 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1196 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1207 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1440 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1097 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1113 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1099 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1095 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1101 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1097 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1118 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1091 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1086 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1040 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1156 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1043 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1139 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1066 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1087 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1107 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1071 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1064 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1174 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1201 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1159 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1097 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1142 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1106 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1110 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1103 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1129 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1088 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1088 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1125 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1104 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1073 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1074 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1070 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1186 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1106 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1163 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1140 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1273 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1186 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1308 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1223 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1396 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1088 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1085 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1071 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1144 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1155 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1177 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1158 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1187 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1156 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1131 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1026 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1054 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1087 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1092 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1188 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1263 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1099 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1117 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1108 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1126 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1098 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1091 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1120 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1107 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1095 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1063 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1121 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1119 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1081 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1076 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1087 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1091 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1073 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1063 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1108 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1109 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1298 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1054 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1275 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1212 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1143 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1062 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1071 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1068 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1095 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1132 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1072 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1165 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1080 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1153 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1068 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1070 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1066 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1070 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1190 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1248 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1248 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1092 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1141 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1099 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1082 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1071 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1099 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1194 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1140 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1077 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1115 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1089 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1076 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1094 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1097 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1065 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1222 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1072 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1102 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1219 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1200 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1113 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1121 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1101 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1122 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1210 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1072 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1061 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1121 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1093 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1118 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1122 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1155 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1102 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1212 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1074 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1081 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1076 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1119 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1388 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1097 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1070 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1142 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1137 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1149 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1047 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1086 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1106 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1119 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1096 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1098 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1077 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1134 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1155 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1134 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1149 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1295 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1179 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1388 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1315 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1168 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1297 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1148 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1077 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1261 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1158 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1091 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1073 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1115 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1070 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1229 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1118 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1083 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1083 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1083 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1113 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1091 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1167 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1118 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1150 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1165 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1138 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1197 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1134 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1177 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1093 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1113 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1120 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1115 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1303 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1316 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1335 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1207 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1222 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1083 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1120 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1069 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1203 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1223 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1128 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1122 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1114 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1120 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1124 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1100 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1039 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1157 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1063 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1178 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1097 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1124 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1084 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1130 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1141 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1091 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1111 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1057 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1117 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1288 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1147 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1071 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1067 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1072 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1069 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1116 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1088 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1098 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1127 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1089 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1114 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1121 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1089 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1086 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1086 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1198 seconds.
# Objective function: 'WLS'| model 'MI' | CPU time 0.1096 seconds.
# ...
# Objective function: 'WLS'| model 'MII' | CPU time 0.1198 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1253 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1143 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1176 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1173 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1185 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1267 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1148 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1336 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1423 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1218 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1099 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1224 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1107 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1174 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1095 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1180 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1105 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1178 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1159 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1203 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1221 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1207 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1226 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1177 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1195 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1167 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1197 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1299 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1152 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1104 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1127 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1166 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1162 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1216 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1120 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1137 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1225 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1135 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1110 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1167 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1125 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1173 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1072 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1137 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1086 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1234 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1188 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1227 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1146 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1209 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1180 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1118 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1098 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1151 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1140 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1279 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1144 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1205 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1106 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1119 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1127 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1187 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1098 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1079 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1108 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1167 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1179 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1194 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1143 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1195 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1102 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1072 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1152 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1287 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1173 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1205 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1166 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1147 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1129 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1173 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1134 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1149 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1579 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1425 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1123 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1274 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1113 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1093 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1132 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1216 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1098 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1143 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1111 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1154 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1176 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1146 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1162 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1175 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1176 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1188 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1146 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1185 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1173 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1141 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1253 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1354 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1171 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1315 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1225 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1285 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1143 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1245 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1117 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1198 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1183 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1219 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1164 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1165 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1171 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1235 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1149 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1194 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1587 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1381 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1172 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1305 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1345 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1193 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1126 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1166 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1155 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1315 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1357 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1448 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1330 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1205 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1103 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1152 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1162 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1175 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1214 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1151 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1149 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1205 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1176 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1186 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1178 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1213 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1180 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1242 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1173 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1212 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1187 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1276 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1573 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1166 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1278 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1265 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1215 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1196 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1547 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1671 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1390 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1575 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1401 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1272 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1271 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1258 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1205 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1292 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1188 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1306 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1304 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1324 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1224 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1288 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1297 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1318 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1732 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1290 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1337 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1305 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1156 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1209 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1138 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1178 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1356 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1286 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1165 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1178 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1425 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1658 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1295 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1316 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1427 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1377 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1396 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1266 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1180 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1245 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1224 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1223 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1251 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1235 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1128 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1161 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1125 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1167 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1113 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1241 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1127 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1221 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1169 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1161 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1156 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1166 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1187 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1178 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1106 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1224 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1261 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1184 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1164 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1152 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1202 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1143 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1107 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1103 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1178 seconds.
# Objective function: 'WLS'| model 'MII' | CPU time 0.1237 seconds.
# Estimated parameters of MI: [0.24075001304568913, 0.22381909515384543, 0.8583774416503711, 0.0830074894658461]
# LS objective function value for MI: 29.797173078852552
# T-values of model MI: [77.52164207 16.17478357 61.54870629 27.61653402]
# P-value of model:MI is 99.83122471865096 for model discrimination
# R2 values for responses in model MI:
#   y1: 0.9348
#   y2: 0.9901
# Estimated parameters of MII: [0.25966625177550257, 0.01768984984095482, 0.8750161533528541, 0.12169178672415691]
# LS objective function value for MII: 114.5533537245665
# T-values of model MII: [47.67897506 13.47218416 40.75341726 22.16996735]
# P-value of model:MII is 0.16877528134904818 for model discrimination
# R2 values for responses in model MII:
#   y1: 0.7416
#   y2: 0.9649

# %%
round = 2
trv=save_rounds(round, resultun,  'MBDOE_MD', round_data, models, iden_opt, obs, data, system)
# Out:
# C:\Users\Tadmin\PycharmProjects\middoe\middoe\iden_utils.py:531: RuntimeWarning: invalid value encountered in sqrt
#   width, height = 2 * np.sqrt(vals)
# reference t value for model MI and round 2: 2.003240718847872
# estimated t values for model MI and round 2: [77.52164207 16.17478357 61.54870629 27.61653402]
# P-value for model MI and round 2: 99.83122471865096
# eps for model MI and round 2: 0.001
# reference t value for model MII and round 2: 2.003240718847872
# estimated t values for model MII and round 2: [47.67897506 13.47218416 40.75341726 22.16996735]
# P-value for model MII and round 2: 0.16877528134904818
# eps for model MII and round 2: 0.001

# %%
from middoe.log_utils import save_to_jac
save_to_jac(round_data, purpose="iden")
# Out:
# [INFO] Results saved to: C:\Users\Tadmin\PycharmProjects\middoe\tests\paper\CS1\iden_results.jac

# %%
from middoe.log_utils import load_from_jac
results = load_from_jac()
iden = results['iden']

from middoe.iden_utils import run_postprocessing
run_postprocessing(
    round_data=results['iden'],
    solvers=['MI', 'MII'],
    selected_rounds=[ 1, 2],
    plot_global_p_and_t=True,
    plot_confidence_spaces=True,
    plot_p_and_t_tests=True,
    export_excel_reports=True,
    plot_estimability=True
)
# Out:
# INFO:middoe.iden_utils:Starting pcomp_plot.
# Loaded: iden_results.jac
# File not found: sensa_results.jac
# INFO:middoe.iden_utils:P values plot for Round 1 saved to C:\Users\Tadmin\PycharmProjects\middoe\tests\paper\CS1\post_processing\p_values_round_1.png.
# INFO:middoe.iden_utils:P values plot for Round 2 saved to C:\Users\Tadmin\PycharmProjects\middoe\tests\paper\CS1\post_processing\p_values_round_2.png.
# INFO:middoe.iden_utils:Starting tcomp_plot.
# INFO:middoe.iden_utils:T values plot for Round 1 saved to C:\Users\Tadmin\PycharmProjects\middoe\tests\paper\CS1\post_processing\t_values_round_1.png.
# INFO:middoe.iden_utils:T values plot for Round 2 saved to C:\Users\Tadmin\PycharmProjects\middoe\tests\paper\CS1\post_processing\t_values_round_2.png.
# Post-processing model: MI
# INFO:middoe.iden_utils:Reporter wrote data for Round 1 to 'C:\Users\Tadmin\PycharmProjects\middoe\tests\paper\CS1\post_processing\MI_report_1.xlsx'.
# INFO:middoe.iden_utils:Reporter wrote data for Round 2 to 'C:\Users\Tadmin\PycharmProjects\middoe\tests\paper\CS1\post_processing\MI_report_2.xlsx'.
# INFO:middoe.iden_utils:Summary written to 'C:\Users\Tadmin\PycharmProjects\middoe\tests\paper\CS1\post_processing\MI_report_summary.txt'.
# No rCC_values found for any round. Plotting is skipped.
# Post-processing model: MII
# INFO:middoe.iden_utils:Reporter wrote data for Round 1 to 'C:\Users\Tadmin\PycharmProjects\middoe\tests\paper\CS1\post_processing\MII_report_1.xlsx'.
# INFO:middoe.iden_utils:Reporter wrote data for Round 2 to 'C:\Users\Tadmin\PycharmProjects\middoe\tests\paper\CS1\post_processing\MII_report_2.xlsx'.
# INFO:middoe.iden_utils:Summary written to 'C:\Users\Tadmin\PycharmProjects\middoe\tests\paper\CS1\post_processing\MII_report_summary.txt'.
# No rCC_values found for any round. Plotting is skipped.
# Post-processing completed for: MI, MII
